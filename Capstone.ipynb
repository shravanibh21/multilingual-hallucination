# %% [markdown]
# # Quickstart

# %%
# Mounting drive to use knowledge source hosted in google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Version comptability with Multi-fact repo
# !pip install transformers==4.41.0 sentence-transformers==3.0.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 123.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 136.8 MB/s eta 0:00:00

# %%
import os
import sys

os.chdir("/content/drive/MyDrive/multilingual-hallucination")  # go into repo
sys.path.append(os.getcwd())  # add correct path

print(os.getcwd())  # sanity check
# Out:
# /content/drive/MyDrive/multilingual-hallucination

# %%
from factscore.factscorer import FactScorer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# This is a very basic example of how to get started. For more details, please check out the original implementation [readme](https://github.com/shmsw25/FActScore) file

# %%
import json, os

os.environ["CUDA_VISIBLE_DEVICES"] = "0" # set you GPU here, optional

# %%
from factscore.factscorer import FactScorer


# Initialize factscorer
fs = FactScorer(openai_key="./openai-api.txt", data_dir="/content/drive/MyDrive/factscore_data",
                fact_generation_type="Mistral", model_name="retrieval+mistral"
                )

# You have the folliowing options for fact_generation_type: InstructGPT (make sure you have a valid openai_key), or Mistral
# You have the following options for model_name: "retrieval+ChatGPT", "npm", "retrieval+ChatGPT+npm", "retrieval+mistral", "retrieval+mistral+npm"
# in the data_dir, put the path where you put your wikipedia database
# Out:
# Using retrieval+mistral
# Mistral model loading
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     632
# --> 633         download_files(
#     634             xet_download_info,
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1174     with WeakFileLock(lock_path):
# -> 1175         _download_to_tmp_and_move(
#    1176             incomplete_path=Path(blob_path + ".incomplete"),
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1726             logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1727             xet_get(
#    1728                 incomplete_path=incomplete_path,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     627
# --> 628     with progress_cm as progress:
#     629
#
# /usr/local/lib/python3.12/dist-packages/tqdm/std.py in __exit__(self, exc_type, exc_value, traceback)
#    1137
# -> 1138     def __exit__(self, exc_type, exc_value, traceback):
#    1139         try:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1595/1584445069.py in <cell line: 0>()
#       3
#       4 # Initialize factscorer
# ----> 5 fs = FactScorer(openai_key="./openai-api.txt", data_dir="/content/drive/MyDrive/factscore_data",
#       6                 fact_generation_type="Mistral", model_name="retrieval+mistral"
#       7                 )
#
# /content/drive/MyDrive/multilingual-hallucination/factscore/factscorer.py in __init__(self, model_name, data_dir, model_dir, cache_dir, openai_key, cost_estimate, abstain_detection_type, batch_size, fact_generation_type)
#      63             self.lm = Mistral_LM("mistralai/Mistral-7B-Instruct-v0.2", cache_file=os.path.join(self.cache_dir, "Mistral.pkl"))
#      64             print("Mistral model loading")
# ---> 65             self.lm.load_model()
#      66             print("Mistral model loaded")
#      67         else:
#
# /content/drive/MyDrive/multilingual-hallucination/factscore/clm.py in load_model(self)
#      34
#      35         # self.model = AutoModelForCausalLM.from_pretrained(self.model_dir, device_map="auto", load_in_4bit=True)
# ---> 36         self.model = AutoModelForCausalLM.from_pretrained(self.model_dir, device_map="auto", torch_dtype=torch.float16)
#      37
#      38
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
#     564                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3509         if is_sharded:
#    3510             # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3511             resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3512                 pretrained_model_name_or_path,
#    3513                 resolved_archive_file,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1038         try:
#    1039             # Load from URL
# -> 1040             cached_filename = cached_file(
#    1041                 pretrained_model_name_or_path,
#    1042                 shard_filename,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     397     try:
#     398         # Load from URL or cache if already cached
# --> 399         resolved_file = hf_hub_download(
#     400             path_or_repo_id,
#     401             filename,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1012         )
#    1013     else:
# -> 1014         return _hf_hub_download_to_cache_dir(
#    1015             # Destination
#    1016             cache_dir=cache_dir,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1172     # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1173
# -> 1174     with WeakFileLock(lock_path):
#    1175         _download_to_tmp_and_move(
#    1176             incomplete_path=Path(blob_path + ".incomplete"),
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     139             raise RuntimeError("generator didn't yield") from None
#     140
# --> 141     def __exit__(self, typ, value, traceback):
#     142         if typ is None:
#     143             try:
#
# KeyboardInterrupt:

# %% [markdown]
# Let's work with one given example. This is GPT4 generation in Chinese, which has been translated into English.

# %%
# read json
with open("generated_bios/translated2en/gpt4-en-translated/Chinese_2en_bios.json", "r") as f:
    bios = json.load(f)

# %%
# let's take one example
topic = "Xi Jinping"
bio = bios[topic] # get the model generated bio

# %%
# now get FActScore:
out = fs.get_score([topic], [bio], gamma=10)
print(f"Topic: {topic}\nFActScore: {out['score']}\nFActScore w/o length penalty: {out['init_score']}\n% of responding (not abstaining from answering): {out['respond_ratio']}\nnum of facts per response: {out['num_facts_per_response']}\n")
# Out:
# <class 'torch.Tensor'> torch.Size([1, 803])
# <class 'torch.Tensor'> torch.Size([1, 776])
# <class 'torch.Tensor'> torch.Size([1, 766])
# <class 'torch.Tensor'> torch.Size([1, 782])
# <class 'torch.Tensor'> torch.Size([1, 783])
# <class 'torch.Tensor'> torch.Size([1, 779])
# <class 'torch.Tensor'> torch.Size([1, 806])
# <class 'torch.Tensor'> torch.Size([1, 780])
# <class 'torch.Tensor'> torch.Size([1, 767])
# <class 'torch.Tensor'> torch.Size([1, 788])
# <class 'torch.Tensor'> torch.Size([1, 780])
# <class 'torch.Tensor'> torch.Size([1, 797])
# <class 'torch.Tensor'> torch.Size([1, 767])
# <class 'torch.Tensor'> torch.Size([1, 790])
# <class 'torch.Tensor'> torch.Size([1, 796])
# <class 'torch.Tensor'> torch.Size([1, 793])
# <class 'torch.Tensor'> torch.Size([1, 781])
# <class 'torch.Tensor'> torch.Size([1, 798])
# <class 'torch.Tensor'> torch.Size([1, 766])
# <class 'torch.Tensor'> torch.Size([1, 799])
# <class 'torch.Tensor'> torch.Size([1, 788])
# <class 'torch.Tensor'> torch.Size([1, 808])
# <class 'torch.Tensor'> torch.Size([1, 792])
# <class 'torch.Tensor'> torch.Size([1, 769])
# <class 'torch.Tensor'> torch.Size([1, 798])
# <class 'torch.Tensor'> torch.Size([1, 794])
# <class 'torch.Tensor'> torch.Size([1, 800])
# <class 'torch.Tensor'> torch.Size([1, 800])
# <class 'torch.Tensor'> torch.Size([1, 766])
# <class 'torch.Tensor'> torch.Size([1, 782])
# <class 'torch.Tensor'> torch.Size([1, 772])
# <class 'torch.Tensor'> torch.Size([1, 767])
# <class 'torch.Tensor'> torch.Size([1, 807])
# <class 'torch.Tensor'> torch.Size([1, 787])
# <class 'torch.Tensor'> torch.Size([1, 784])
# <class 'torch.Tensor'> torch.Size([1, 787])
# Topic: Xi Jinping
# FActScore: 0.8716577540106952
# FActScore w/o length penalty: 0.8716577540106952
# % of responding (not abstaining from answering): 1.0
# num of facts per response: 187.0

# %%
def print_factscore(lang : str):
  file = f"generated_bios_qwen/translated2en/gpt4-en-translated/{lang}_2en_bios.json"
  with open(file, "r") as f:
    bios = json.load(f)

  topic = "Xi Jinping"
  bio = bios[topic]

  out = fs.get_score([topic], [bio], gamma=20)
  print(f"Language: {lang}\nTopic: {topic}\nFActScore: {out['score']}\nFActScore w/o length penalty: {out['init_score']}\n% of responding (not abstaining from answering): {out['respond_ratio']}\nnum of facts per response: {out['num_facts_per_response']}\n")

# %%
print_factscore("English")
# Out:
# <class 'torch.Tensor'> torch.Size([1, 787])
# <class 'torch.Tensor'> torch.Size([1, 780])
# <class 'torch.Tensor'> torch.Size([1, 806])
# <class 'torch.Tensor'> torch.Size([1, 788])
# <class 'torch.Tensor'> torch.Size([1, 792])
# <class 'torch.Tensor'> torch.Size([1, 791])
# <class 'torch.Tensor'> torch.Size([1, 795])
# <class 'torch.Tensor'> torch.Size([1, 793])
# <class 'torch.Tensor'> torch.Size([1, 794])
# <class 'torch.Tensor'> torch.Size([1, 790])
# <class 'torch.Tensor'> torch.Size([1, 791])
# <class 'torch.Tensor'> torch.Size([1, 790])
# <class 'torch.Tensor'> torch.Size([1, 783])
# <class 'torch.Tensor'> torch.Size([1, 792])
# <class 'torch.Tensor'> torch.Size([1, 790])
# <class 'torch.Tensor'> torch.Size([1, 797])
# <class 'torch.Tensor'> torch.Size([1, 806])
# <class 'torch.Tensor'> torch.Size([1, 783])
# <class 'torch.Tensor'> torch.Size([1, 784])
# <class 'torch.Tensor'> torch.Size([1, 783])
# <class 'torch.Tensor'> torch.Size([1, 789])
# <class 'torch.Tensor'> torch.Size([1, 797])
# <class 'torch.Tensor'> torch.Size([1, 781])
# Language: English
# Topic: Xi Jinping
# FActScore: 0.8380281690140845
# FActScore w/o length penalty: 0.8380281690140845
# % of responding (not abstaining from answering): 1.0
# num of facts per response: 142.0

# %%
print_factscore("Hindi")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1595/2555606618.py in <cell line: 0>()
# ----> 1 print_factscore("Hindi")
#
# /tmp/ipykernel_1595/2267029559.py in print_factscore(lang)
#       1 def print_factscore(lang : str):
#       2   file = f"generated_bios_qwen/translated2en/gpt4-en-translated/{lang}_2en_bios.json"
# ----> 3   with open(file, "r") as f:
#       4     bios = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'generated_bios_qwen/translated2en/gpt4-en-translated/Hindi_2en_bios.json'

# %%
print_factscore("Bengali")
# Out:
# <class 'torch.Tensor'> torch.Size([1, 794])
# <class 'torch.Tensor'> torch.Size([1, 796])
# <class 'torch.Tensor'> torch.Size([1, 764])
# <class 'torch.Tensor'> torch.Size([1, 794])
# <class 'torch.Tensor'> torch.Size([1, 796])
# <class 'torch.Tensor'> torch.Size([1, 765])
# <class 'torch.Tensor'> torch.Size([1, 776])
# <class 'torch.Tensor'> torch.Size([1, 775])
# <class 'torch.Tensor'> torch.Size([1, 792])
# <class 'torch.Tensor'> torch.Size([1, 765])
# <class 'torch.Tensor'> torch.Size([1, 776])
# <class 'torch.Tensor'> torch.Size([1, 775])
# <class 'torch.Tensor'> torch.Size([1, 775])
# Language: Bengali
# Topic: Xi Jinping
# FActScore: 0.10810810810810811
# FActScore w/o length penalty: 0.10810810810810811
# % of responding (not abstaining from answering): 1.0
# num of facts per response: 37.0

# %%
print_factscore("Swahili")
# Out:
# <class 'torch.Tensor'> torch.Size([1, 785])
# <class 'torch.Tensor'> torch.Size([1, 789])
# Language: Swahili
# Topic: Xi Jinping
# FActScore: 0.8461538461538461
# FActScore w/o length penalty: 0.8461538461538461
# % of responding (not abstaining from answering): 1.0
# num of facts per response: 13.0
